# %%
import pandas as pd

# %%
x=pd.read_excel('/content/test_123.xlsx', sheet_name=None)

# %%
x1=pd.read_csv('/content/test_123.csv')

# %%
x1
# Out:
#              Visits Visit 0 Stabilization Visit 1 Screening  \
# 0  Informed consent                   yes               yes
# 1                 y                   yes               yes
# 2                 u                   yes               yes
# 3                 t                   yes               yes
# 4                 r                   yes               yes
# 5                 e                   yes               yes
#
#    Visit 1.1 Baseline  Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# 0                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 1                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 2                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 3                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 4                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
df=x1

# %%
df
# Out:
#              Visits Visit 0 Stabilization Visit 1 Screening  \
# 0  Informed consent                   yes               yes
# 1                 y                   yes               yes
# 2                 u                   yes               yes
# 3                 t                   yes               yes
# 4                 r                   yes               yes
# 5                 e                   yes               yes
#
#    Visit 1.1 Baseline  Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# 0                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 1                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 2                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 3                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 4                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
null_cols = df.columns[df.isnull().all()]
df.drop(null_cols, axis = 1, inplace = True)

# %%
df
# Out:
#              Visits Visit 0 Stabilization Visit 1 Screening
# 0  Informed consent                   yes               yes
# 1                 y                   yes               yes
# 2                 u                   yes               yes
# 3                 t                   yes               yes
# 4                 r                   yes               yes
# 5                 e                   yes               yes

# %%
df.set_index("Visits", inplace = True)

# %%
df.loc['Informed consent' , : ]
df.loc['y' , : ]
# Out:
# Visit 0 Stabilization    yes
# Visit 1 Screening        yes
# Name: y, dtype: object

# %%
x1
# Out:
#                  Visit 0 Stabilization Visit 1 Screening  Visit 1.1 Baseline  \
# Visits
# Informed consent                   yes               yes                 NaN
# y                                  yes               yes                 NaN
# u                                  yes               yes                 NaN
# t                                  yes               yes                 NaN
# r                                  yes               yes                 NaN
# e                                  yes               yes                 NaN
#
#                   Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# Visits
# Informed consent               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# y                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# u                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# t                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
x1.set_index("Visits", inplace = True)

# %%
z=x1.columns[x1.notnull().all()]

# %%
z1=x1[z]

# %%
z1.loc['Informed consent' , : ]
# Out:
# Visit 0 Stabilization    yes
# Visit 1 Screening        yes
# Name: Informed consent, dtype: object

# %%
****************

# %%
import pandas as pd
x1=pd.read_csv('/content/test_123.csv')

# %%
x1
# Out:
#                  Visit 0 Stabilization Visit 1 Screening  Visit 1.1 Baseline  \
# Visits
# Informed consent                   yes               yes                 NaN
# y                                  yes               yes                 NaN
# u                                  yes               yes                 NaN
# t                                  yes               yes                 NaN
# r                                  yes               yes                 NaN
# e                                  yes               yes                 NaN
#
#                   Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# Visits
# Informed consent               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# y                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# u                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# t                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
x1.set_index("Visits", inplace = True)

# %%
ic=x1.loc['Informed consent' , : ]

# %%
type(ic)
# Out:
# pandas.core.series.Series

# %%
df_2 = ic.to_frame()#.reset_index()

# %%
df_2
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes
# Visit 1.1 Baseline                 NaN
# Visit 2 Baseline                   NaN
# V2.1                               NaN
# V2.3                               NaN
# V3                                 NaN
# V4                                 NaN
# V5                                 NaN
# V6                                 NaN
# V7                                 NaN
# V7.1                               NaN
# V7.2                               NaN
# V7.3                               NaN
# V8                                 NaN
# V8.1                               NaN
# V9                                 NaN

# %%
no_nans = df_2[~df_2.isnull().any(axis=1)]

# %%
no_nans
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes

# %%
#zz=x1.loc['Informed consent' , : ].notna()

# %%
zz
# Out:
# Visit 0 Stabilization    yes
# Visit 1 Screening        yes
# Visit 1.1 Baseline       NaN
# Visit 2 Baseline         NaN
# V2.1                     NaN
# V2.3                     NaN
# V3                       NaN
# V4                       NaN
# V5                       NaN
# V6                       NaN
# V7                       NaN
# V7.1                     NaN
# V7.2                     NaN
# V7.3                     NaN
# V8                       NaN
# V8.1                     NaN
# V9                       NaN
# Name: Informed consent, dtype: object

# %%
z=x1.columns[x1.notnull().all()]
z1=x1[z]
zz=x1.loc['Informed consent' , : ]

# %%
******************************************

# %%
import pandas as pd
data=pd.read_csv('/content/test_123.csv')

# %%
data
# Out:
#              Visits Visit 0 Stabilization Visit 1 Screening  \
# 0  Informed consent                   yes               yes
# 1                 y                   yes               yes
# 2                 u                   yes               yes
# 3                 t                   yes               yes
# 4                 r                   yes               yes
# 5                 e                   yes               yes
#
#    Visit 1.1 Baseline  Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# 0                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 1                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 2                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 3                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# 4                 NaN               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
data.set_index("Visits", inplace = True)

# %%
data
# Out:
#                  Visit 0 Stabilization Visit 1 Screening  Visit 1.1 Baseline  \
# Visits
# Informed consent                   yes               yes                 NaN
# y                                  yes               yes                 NaN
# u                                  yes               yes                 NaN
# t                                  yes               yes                 NaN
# r                                  yes               yes                 NaN
# e                                  yes               yes                 NaN
#
#                   Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# Visits
# Informed consent               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# y                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# u                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# t                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
list_1=['informed consent','u']
for i in list_1:
  print (i)
# Out:
# informed consent
# u

# %%
data
# Out:
#                  Visit 0 Stabilization Visit 1 Screening  Visit 1.1 Baseline  \
# Visits
# Informed consent                   yes               yes                 NaN
# y                                  yes               yes                 NaN
# u                                  yes               yes                 NaN
# t                                  yes               yes                 NaN
# r                                  yes               yes                 NaN
# e                                  yes               yes                 NaN
#
#                   Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# Visits
# Informed consent               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# y                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# u                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# t                              NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
# ...

# %%
test_1=data.loc['Informed consent' , : ]

# %%
list=['Informed consent','u']
for i in list:
  ic=data.loc[i , : ]
  df_2 = ic.to_frame()
  output = df_2[~df_2.isnull().any(axis=1)]
  print (output)
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes
#                          u
# Visit 0 Stabilization  yes
# Visit 1 Screening      yes

# %%
ic
# Out:
#                  Visit 0 Stabilization Visit 1 Screening  Visit 1.1 Baseline  \
# Visits
# Informed consent                   yes               yes                 NaN
#
#                   Visit 2 Baseline  V2.1  V2.3  V3  V4  V5  V6  V7  V7.1  \
# Visits
# Informed consent               NaN   NaN   NaN NaN NaN NaN NaN NaN   NaN
#
#                   V7.2  V7.3  V8  V8.1  V9
# Visits
# Informed consent   NaN   NaN NaN   NaN NaN

# %%
df_2
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes
# Visit 1.1 Baseline                 NaN
# Visit 2 Baseline                   NaN
# V2.1                               NaN
# V2.3                               NaN
# V3                                 NaN
# V4                                 NaN
# V5                                 NaN
# V6                                 NaN
# V7                                 NaN
# V7.1                               NaN
# V7.2                               NaN
# V7.3                               NaN
# V8                                 NaN
# V8.1                               NaN
# V9                                 NaN

# %%
output = df_2[~df_2.isnull().any(axis=1)]

# %%
output
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes

# %%
out_1 = df_2[df_2.columns[~df_2.isnull().all()]]

# %%
out_1
# Out:
#                       Informed consent
# Visit 0 Stabilization              yes
# Visit 1 Screening                  yes
# Visit 1.1 Baseline                 NaN
# Visit 2 Baseline                   NaN
# V2.1                               NaN
# V2.3                               NaN
# V3                                 NaN
# V4                                 NaN
# V5                                 NaN
# V6                                 NaN
# V7                                 NaN
# V7.1                               NaN
# V7.2                               NaN
# V7.3                               NaN
# V8                                 NaN
# V8.1                               NaN
# V9                                 NaN

# %%
***************************************

# %%
import pandas as pd
data=pd.read_csv('/content/test_123.csv')

# %%
data
# Out:
#                           Visits Visit 0 Stabilization Visit 1 Screening  \
# 0               Informed consent                     .                 .
# 1   Inclusion/exclusion criteria                     .                 .
# 2  Stable conventional treatment                     .                 .
# 3                    HIV HBV HCV                     .                 .
# 4                             TB                     .                 .
#
#    Visit 1.1 Baseline Visit 2 Baseline  V2.1  V2.3   V3  V4  V5  V6   V7  \
# 0                 NaN              NaN   NaN   NaN  NaN NaN NaN NaN  NaN
# 1                 NaN              NaN   NaN   NaN  NaN NaN NaN NaN    .
# 2                 NaN              NaN   NaN   NaN    . NaN NaN NaN  NaN
# 3                 NaN                .   NaN   NaN  NaN NaN NaN NaN  NaN
# 4                 NaN              NaN   NaN   NaN  NaN NaN NaN NaN  NaN
#
#    V7.1  V7.2  V7.3  V8  V8.1  V9
# 0   NaN   NaN   NaN NaN   NaN NaN
# ...

# %%
data.set_index("Visits", inplace = True)

# %%
data
# Out:
#                               Visit 0 Stabilization Visit 1 Screening  \
# Visits
# Informed consent                                  .                 .
# Inclusion/exclusion criteria                      .                 .
# Stable conventional treatment                     .                 .
# HIV HBV HCV                                       .                 .
# TB                                                .                 .
#
#                                Visit 1.1 Baseline Visit 2 Baseline  V2.1  \
# Visits
# Informed consent                              NaN              NaN   NaN
# Inclusion/exclusion criteria                  NaN              NaN   NaN
# Stable conventional treatment                 NaN              NaN   NaN
# HIV HBV HCV                                   NaN                .   NaN
# TB                                            NaN              NaN   NaN
#
#                                V2.3   V3  V4  V5  V6   V7  V7.1  V7.2  V7.3  \
# Visits
# ...

# %%
list=['Informed consent','Inclusion/exclusion criteria','Stable conventional treatment', 'TB']

# %%
for i in list:
  ic=data.loc[i , : ]
  df_2 = ic.to_frame()
  output = df_2[~df_2.isnull().any(axis=1)]
  print (output)
# Out:
#                       Informed consent
# Visit 0 Stabilization                .
# Visit 1 Screening                    .
#                       Inclusion/exclusion criteria
# Visit 0 Stabilization                            .
# Visit 1 Screening                                .
# V7                                               .
#                       Stable conventional treatment
# Visit 0 Stabilization                             .
# Visit 1 Screening                                 .
# V3                                                .
#                       TB
# Visit 0 Stabilization  .
# Visit 1 Screening      .
